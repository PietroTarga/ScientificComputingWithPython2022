# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset simulating 3 features, each with N entries (N being ${\cal O}(1000)$). Each feature is made by random numbers generated according the normal distribution $N(\mu,\sigma)$ with mean $\mu_i$ and standard deviation $\sigma_i$, with $i=1, 2, 3$. Generate the 3 variables $x_{i}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues using the eigendecomposition of the covariance matrix
# * Find the eigenvectors and eigenvalues using the SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained
# * Redefine the data according to the new basis from the PCA
# * Plot the data, in both the original and the new basis. The figure should have 2 rows (the original and the new basis) and 3 columns (the $[x_0, x_1]$, $[x_0, x_2]$ and $[x_1, x_2]$ projections) of scatter plots.

# %%
import pandas as pd
import numpy as np
from scipy import linalg as la
import matplotlib.pyplot as plt

#Data set generation
n = 1000

x1 = np.random.normal(loc=0, scale=1, size=n)
x2 = x1 + np.random.normal(loc=0, scale=3, size=n)
x3 = 2*x1+x2

df = np.array([x1, x2, x3])


#eigenvectors and eigenvalues

print('Using eigendecomposition')

np_cov = np.cov(df)

l, V = la.eig(np_cov)
print('Eigenvalues: ',np.real_if_close(l))
print('Eigenvectors: ')
print(V,'\n\n')



print('Using SVD')

U, S, Vt = la.svd(df)

l = np.diag(np.reshape(S, (len(S),1))*S)/(n-1)

print('Eigenvalues: ',l)

print('Eigenvectors: ')
print(U, '\n\n')




#Principal components analysis


print("By selecting the component 0, we retain %.2f%% of the total variability" % (100*l[0]/np.sum(l)))
print("By selecting the component 1, we retain %.2f%% of the total variability" % (100*l[1]/np.sum(l)))
print("By selecting the component 2, we retain %.2f%% of the total variability" % (100*l[2]/np.sum(l)))


print('In order to retain over the 99% of the vatiability we must select the first two components')

df_p = np.dot(U.T, df)

fig,ax = plt.subplots(2,3,figsize=(14, 8))

ax[0,1].set_title('Data in the original and new basis')
ax[0,0].scatter(df[0,:], df[1,:], alpha=0.2)
ax[0,0].set_xlim([-15,15])
ax[0,0].set_ylim([-15,15])
ax[0,0].set_xlabel('x1')
ax[0,0].set_ylabel('x2')
ax[0,1].scatter(df[0,:], df[2,:], alpha=0.2)
ax[0,1].set_xlim([-15,15])
ax[0,1].set_ylim([-15,15])
ax[0,1].set_xlabel('x1')
ax[0,1].set_ylabel('x3')
ax[0,2].scatter(df[1,:], df[2,:], alpha=0.2)
ax[0,2].set_xlim([-15,15])
ax[0,2].set_ylim([-15,15])
ax[0,2].set_xlabel('x2')
ax[0,2].set_ylabel('x3')


ax[1,0].scatter(df_p[0,:], df_p[1,:], alpha=0.2)
ax[1,0].set_xlim([-15,15])
ax[1,0].set_ylim([-15,15])
ax[1,0].set_xlabel('x1 new basis')
ax[1,0].set_ylabel('x2 new basis')
ax[1,1].scatter(df_p[0,:], df_p[2,:], alpha=0.2)
ax[1,1].set_xlim([-15,15])
ax[1,1].set_ylim([-15,15])
ax[1,1].set_xlabel('x1 new basis')
ax[1,1].set_ylabel('x3 new basis')
ax[1,2].scatter(df_p[1,:], df_p[2,:], alpha=0.2)
ax[1,2].set_xlim([-15,15])
ax[1,2].set_ylim([-15,15])
ax[1,2].set_xlabel('x2 new basis')
ax[1,2].set_ylabel('x3 new basis')

plt.show()
# Out:
# Using eigendecomposition
# Eigenvalues:  [ 2.58601055e+01 -1.77172208e-16  2.03687867e+00]
# Eigenvectors:
# [[-0.11500361 -0.81649658  0.56578044]
#  [-0.57793308 -0.40824829 -0.70663052]
#  [-0.8079403   0.40824829  0.42493035]]
#
#
# Using SVD
# Eigenvalues:  [2.58606014e+01 2.04049211e+00 9.26414411e-30]
# Eigenvectors:
# [[-0.1150354   0.56577397 -0.81649658]
#  [-0.57789337 -0.70666299 -0.40824829]
#  [-0.80796418  0.42488495  0.40824829]]
#
#
# By selecting the component 0, we retain 92.69% of the total variability
# By selecting the component 1, we retain 7.31% of the total variability
# By selecting the component 2, we retain 0.00% of the total variability
# In order to retain over the 99% of the vatiability we must select the first two components

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# * Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normally distributed, with a standard deviation much smaller (e.g. a factor 20) than those used to generate the $x_1$ and $x_2$. Repeat the PCA procedure and compare the results with what you have obtained before.

# %%
df = np.array([x1,x2,x3])
x4 = np.random.normal(loc=0, scale=1/20, size=(10,n))
df = np.append(df, x4, axis=0)

U, S, Vt = la.svd(df)

l = np.diag(np.reshape(S, (len(S),1))*S)/(n-1)



print("By selecting the component 0, we retain %.2f%% of the total variability" % (100*l[0]/np.sum(l)))
print("By selecting the component 1, we retain %.2f%% of the total variability" % (100*l[1]/np.sum(l)))
print("By selecting the component 2, we retain %.2f%% of the total variability" % (100*l[2]/np.sum(l)))


df_p = np.dot(U.T, df)

fig,ax = plt.subplots(2,3,figsize=(14, 8))

ax[0,1].set_title('Data in the original and new basis')
ax[0,0].scatter(df[0,:], df[1,:], alpha=0.2)
ax[0,0].set_xlim([-15,15])
ax[0,0].set_ylim([-15,15])
ax[0,0].set_xlabel('x1')
ax[0,0].set_ylabel('x2')
ax[0,1].scatter(df[0,:], df[2,:], alpha=0.2)
ax[0,1].set_xlim([-15,15])
ax[0,1].set_ylim([-15,15])
ax[0,1].set_xlabel('x1')
ax[0,1].set_ylabel('x3')
ax[0,2].scatter(df[1,:], df[2,:], alpha=0.2)
ax[0,2].set_xlim([-15,15])
ax[0,2].set_ylim([-15,15])
ax[0,2].set_xlabel('x2')
ax[0,2].set_ylabel('x3')


ax[1,0].scatter(df_p[0,:], df_p[1,:], alpha=0.2)
ax[1,0].set_xlim([-15,15])
ax[1,0].set_ylim([-15,15])
ax[1,0].set_xlabel('x1 new basis')
ax[1,0].set_ylabel('x2 new basis')
ax[1,1].scatter(df_p[0,:], df_p[2,:], alpha=0.2)
ax[1,1].set_xlim([-15,15])
ax[1,1].set_ylim([-15,15])
ax[1,1].set_xlabel('x1 new basis')
ax[1,1].set_ylabel('x3 new basis')
ax[1,2].scatter(df_p[1,:], df_p[2,:], alpha=0.2)
ax[1,2].set_xlim([-15,15])
ax[1,2].set_ylim([-15,15])
ax[1,2].set_xlabel('x2 new basis')
ax[1,2].set_ylabel('x3 new basis')
plt.show()

print('The result does not change much in respect to the previous')
# Out:
# By selecting the component 0, we retain 92.60% of the total variability
# By selecting the component 1, we retain 7.31% of the total variability
# By selecting the component 2, we retain 0.01% of the total variability
# The result does not change much in respect to the previous

# %% [markdown]
# 3\. **Optional**: **PCA on the MAGIC dataset**
#
# Perform a PCA on the magic04.data dataset.

# %%
# get the dataset and its description on the proper data directory
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P data/
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P data/

# %%
df = pd.read_csv('data/magic04.data')
df = pd.DataFrame(df)
df = df.drop('g', axis=1)

df = df.T

l, V = la.eig(np.cov(df))
print(l)
l = np.real(l)

print("By selecting the component 0, we retain %.2f%% of the total variability" % (100*l[0]/np.sum(l)))
print("By selecting the component 1, we retain %.2f%% of the total variability" % (100*l[1]/np.sum(l)))
print("By selecting the component 2, we retain %.2f%% of the total variability" % (100*l[2]/np.sum(l)))
print("By selecting the component 3, we retain %.2f%% of the total variability" % (100*l[3]/np.sum(l)))



print('So in order to get the 90% of the total variability we can keep the first four components')
# Out:
# [6.57940709e+03+0.j 3.85406143e+03+0.j 2.01648128e+03+0.j
#  1.32681867e+03+0.j 6.10218593e+02+0.j 4.33618554e+02+0.j
#  1.17335954e+02+0.j 8.64007193e-02+0.j 1.07368268e-02+0.j
#  3.85330787e-04+0.j]
# By selecting the component 0, we retain 44.04% of the total variability
# By selecting the component 1, we retain 25.80% of the total variability
# By selecting the component 2, we retain 13.50% of the total variability
# By selecting the component 3, we retain 8.88% of the total variability
# So in order to get the 90% of the total variability we can keep the first four components
